# %% [markdown]
# # Primeira parte

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #### Básico

# %%
# https://onlinecsvtools.com/change-csv-delimiter
df = pd.read_csv('dados_consulta_operacional_2020_09_21_2020_09_27.csv', sep = '|', encoding = 'utf-8', decimal = ',')

# %%
df.head(10)
# Out:
#          data tipo_prefixo prefixo    nome_ramal composicao  ar serie extra  \
# 0  2020-09-21           UA   UA003  Belford Roxo       2018  AR  2000   NÃO
# 1  2020-09-21           UA   UA004  Belford Roxo        711  AR   700   NÃO
# 2  2020-09-21           UA   UA005  Belford Roxo        716  AR   700   NÃO
# 3  2020-09-21           UA   UA006  Belford Roxo        714  AR   700   NÃO
# 4  2020-09-21           UA   UA007  Belford Roxo        717  AR   700   NÃO
# 5  2020-09-21           UA   UA008  Belford Roxo       3045  AR  3000   NÃO
# 6  2020-09-21           UA   UA009  Belford Roxo        704  AR   700   NÃO
# 7  2020-09-21           UA   UA010  Belford Roxo       3056  AR  3000   NÃO
# 8  2020-09-21           UA   UA011  Belford Roxo        711  AR   700   NÃO
# 9  2020-09-21           UA   UA012  Belford Roxo       2018  AR  2000   NÃO
#
#    qtd_extras partida_real  ...  capacidade_6m2 ncarros n_TUE origem  destino  \
# 0         0.0     05:19:24  ...          1200.0     4.0   1.0    DPO      BRX
# 1         0.0     05:10:39  ...          1200.0     4.0   1.0    BRX      DPO
# 2         0.0     05:47:55  ...          1200.0     4.0   1.0    DPO      BRX
# 3         0.0     05:33:45  ...          1200.0     4.0   1.0    BRX      DPO
# 4         0.0     06:14:00  ...          1200.0     4.0   1.0    DPO      BRX
# 5         0.0     06:02:04  ...          1200.0     4.0   1.0    BRX      DPO
# 6         0.0     06:36:28  ...          1200.0     4.0   1.0    DPO      BRX
# 7         0.0     06:20:53  ...          1200.0     4.0   1.0    BRX      DPO
# 8         0.0     06:56:27  ...          1200.0     4.0   1.0    DPO      BRX
# 9         0.0     06:41:28  ...          1200.0     4.0   1.0    BRX      DPO
#
#   linha_comercial         linha         km    carro_km velocidade_km_h
# 0         DPO-BRX  Belford Roxo  32.849998  131.399994       26.999998
# 1         BRX-DPO  Belford Roxo  32.849998  131.399994       28.565217
# 2         DPO-BRX  Belford Roxo  32.849998  131.399994       27.760563
# 3         BRX-DPO  Belford Roxo  32.849998  131.399994       27.760563
# 4         DPO-BRX  Belford Roxo  32.849998  131.399994       30.323074
# 5         BRX-DPO  Belford Roxo  32.849998  131.399994       30.796872
# 6         DPO-BRX  Belford Roxo  32.849998  131.399994       29.863634
# 7         BRX-DPO  Belford Roxo  32.849998  131.399994       28.157143
# 8         DPO-BRX  Belford Roxo  32.849998  131.399994       28.985293
# 9         BRX-DPO  Belford Roxo  32.849998  131.399994       27.374998
#
# [10 rows x 52 columns]

# %%
df.shape
# Out:
# (4787, 52)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4787 entries, 0 to 4786
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   data                       4787 non-null   object
#  1   tipo_prefixo               4188 non-null   object
#  2   prefixo                    4188 non-null   object
#  3   nome_ramal                 4188 non-null   object
#  4   composicao                 4087 non-null   object
#  5   ar                         3726 non-null   object
#  6   serie                      3965 non-null   object
#  7   extra                      4188 non-null   object
#  8   qtd_extras                 4188 non-null   float64
#  9   partida_real               4078 non-null   object
#  10  hora_real                  4078 non-null   float64
#  11  periodo_real               4078 non-null   object
#  12  chegada_real               4180 non-null   object
#  13  partida_programada         4188 non-null   object
#  14  hora_programada            4188 non-null   float64
#  15  periodo_prog               4188 non-null   object
#  16  chegada_programada         4188 non-null   object
#  17  maquinista                 4185 non-null   object
#  18  servico                    3367 non-null   object
#  19  tipo_viagem                4188 non-null   object
#  20  viagem_comercial           4188 non-null   object
#  21  descricao_sentido          4188 non-null   object
#  22  siof_viagem_id             4188 non-null   float64
#  23  fluxo_realizados           4188 non-null   object
#  24  fluxo_Programado           4188 non-null   object
#  25  suprimido                  4188 non-null   object
#  26  tempo_percurso_real        4077 non-null   float64
#  27  tempo_percurso_programado  4188 non-null   float64
#  28  min_atraso                 4076 non-null   float64
#  29  programada                 4188 non-null   float64
#  30  realizadas                 4188 non-null   float64
#  31  Suprimidas                 4188 non-null   float64
#  32  atraso_percent             4188 non-null   float64
#  33  atraso_percent_0           4188 non-null   float64
#  34  atraso_percent_5           4188 non-null   float64
#  35  atraso_percent_10          4188 non-null   float64
#  36  num_ocorrencia             467 non-null    float64
#  37  dsc_sintoma_trem_prej      464 non-null    object
#  38  DSC_AREA                   467 non-null    object
#  39  DSC_CAUSA                  0 non-null      float64
#  40  DSC_SINTOMA                467 non-null    object
#  41  expurgar                   4188 non-null   object
#  42  capacidade_6m2             3965 non-null   float64
#  43  ncarros                    3965 non-null   float64
#  44  n_TUE                      4087 non-null   float64
#  45  origem                     4188 non-null   object
#  46  destino                    4188 non-null   object
#  47  linha_comercial            4188 non-null   object
#  48  linha                      4188 non-null   object
#  49  km                         4188 non-null   float64
#  50  carro_km                   3965 non-null   float64
#  51  velocidade_km_h            4076 non-null   float64
# dtypes: float64(22), object(30)
# memory usage: 1.9+ MB

# %%
def unique_col_values(df):
    for column in df:
        print("{} | {} | {}".format(
        df[column].name, len(df[column].unique()),
             df[column].dtype))

unique_col_values(df)
# Out:
# data | 606 | object
# tipo_prefixo | 13 | object
# prefixo | 979 | object
# nome_ramal | 8 | object
# composicao | 165 | object
# ar | 2 | object
# serie | 9 | object
# extra | 3 | object
# qtd_extras | 3 | float64
# partida_real | 3599 | object
# hora_real | 25 | float64
# periodo_real | 5 | object
# chegada_real | 3738 | object
# partida_programada | 979 | object
# hora_programada | 25 | float64
# periodo_prog | 5 | object
# chegada_programada | 1019 | object
# maquinista | 306 | object
# servico | 3 | object
# tipo_viagem | 3 | object
# viagem_comercial | 3 | object
# descricao_sentido | 3 | object
# siof_viagem_id | 4189 | float64
# fluxo_realizados | 3 | object
# fluxo_Programado | 3 | object
# suprimido | 3 | object
# tempo_percurso_real | 171 | float64
# tempo_percurso_programado | 81 | float64
# min_atraso | 122 | float64
# programada | 2 | float64
# realizadas | 3 | float64
# Suprimidas | 3 | float64
# atraso_percent | 358 | float64
# atraso_percent_0 | 3 | float64
# atraso_percent_5 | 3 | float64
# atraso_percent_10 | 3 | float64
# num_ocorrencia | 40 | float64
# dsc_sintoma_trem_prej | 463 | object
# DSC_AREA | 11 | object
# DSC_CAUSA | 1 | float64
# DSC_SINTOMA | 21 | object
# expurgar | 3 | object
# capacidade_6m2 | 6 | float64
# ncarros | 6 | float64
# n_TUE | 5 | float64
# origem | 47 | object
# destino | 52 | object
# linha_comercial | 148 | object
# linha | 15 | object
# km | 101 | float64
# carro_km | 60 | float64
# velocidade_km_h | 590 | float64

# %%
# eliminando linhas com problema de importação
df = df.dropna(subset = ['tipo_prefixo'], axis = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4188 entries, 0 to 4786
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   data                       4188 non-null   object
#  1   tipo_prefixo               4188 non-null   object
#  2   prefixo                    4188 non-null   object
#  3   nome_ramal                 4188 non-null   object
#  4   composicao                 4087 non-null   object
#  5   ar                         3726 non-null   object
#  6   serie                      3965 non-null   object
#  7   extra                      4188 non-null   object
#  8   qtd_extras                 4188 non-null   float64
#  9   partida_real               4078 non-null   object
#  10  hora_real                  4078 non-null   float64
#  11  periodo_real               4078 non-null   object
#  12  chegada_real               4180 non-null   object
#  13  partida_programada         4188 non-null   object
#  14  hora_programada            4188 non-null   float64
#  15  periodo_prog               4188 non-null   object
#  16  chegada_programada         4188 non-null   object
#  17  maquinista                 4185 non-null   object
#  18  servico                    3367 non-null   object
#  19  tipo_viagem                4188 non-null   object
#  20  viagem_comercial           4188 non-null   object
#  21  descricao_sentido          4188 non-null   object
#  22  siof_viagem_id             4188 non-null   float64
#  23  fluxo_realizados           4188 non-null   object
#  24  fluxo_Programado           4188 non-null   object
#  25  suprimido                  4188 non-null   object
#  26  tempo_percurso_real        4077 non-null   float64
#  27  tempo_percurso_programado  4188 non-null   float64
#  28  min_atraso                 4076 non-null   float64
#  29  programada                 4188 non-null   float64
#  30  realizadas                 4188 non-null   float64
#  31  Suprimidas                 4188 non-null   float64
#  32  atraso_percent             4188 non-null   float64
#  33  atraso_percent_0           4188 non-null   float64
#  34  atraso_percent_5           4188 non-null   float64
#  35  atraso_percent_10          4188 non-null   float64
#  36  num_ocorrencia             467 non-null    float64
#  37  dsc_sintoma_trem_prej      464 non-null    object
#  38  DSC_AREA                   467 non-null    object
#  39  DSC_CAUSA                  0 non-null      float64
#  40  DSC_SINTOMA                467 non-null    object
#  41  expurgar                   4188 non-null   object
#  42  capacidade_6m2             3965 non-null   float64
#  43  ncarros                    3965 non-null   float64
#  44  n_TUE                      4087 non-null   float64
#  45  origem                     4188 non-null   object
#  46  destino                    4188 non-null   object
#  47  linha_comercial            4188 non-null   object
#  48  linha                      4188 non-null   object
#  49  km                         4188 non-null   float64
#  50  carro_km                   3965 non-null   float64
#  51  velocidade_km_h            4076 non-null   float64
# dtypes: float64(22), object(30)
# memory usage: 1.7+ MB

# %%
from datetime import datetime

# %%
df['data'] = pd.to_datetime(df['data'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4188 entries, 0 to 4786
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   data                       4188 non-null   datetime64[ns]
#  1   tipo_prefixo               4188 non-null   object
#  2   prefixo                    4188 non-null   object
#  3   nome_ramal                 4188 non-null   object
#  4   composicao                 4087 non-null   object
#  5   ar                         3726 non-null   object
#  6   serie                      3965 non-null   object
#  7   extra                      4188 non-null   object
#  8   qtd_extras                 4188 non-null   float64
#  9   partida_real               4078 non-null   object
#  10  hora_real                  4078 non-null   float64
#  11  periodo_real               4078 non-null   object
#  12  chegada_real               4180 non-null   object
#  13  partida_programada         4188 non-null   object
#  14  hora_programada            4188 non-null   float64
#  15  periodo_prog               4188 non-null   object
#  16  chegada_programada         4188 non-null   object
#  17  maquinista                 4185 non-null   object
#  18  servico                    3367 non-null   object
#  19  tipo_viagem                4188 non-null   object
#  20  viagem_comercial           4188 non-null   object
#  21  descricao_sentido          4188 non-null   object
#  22  siof_viagem_id             4188 non-null   float64
#  23  fluxo_realizados           4188 non-null   object
#  24  fluxo_Programado           4188 non-null   object
#  25  suprimido                  4188 non-null   object
#  26  tempo_percurso_real        4077 non-null   float64
#  27  tempo_percurso_programado  4188 non-null   float64
#  28  min_atraso                 4076 non-null   float64
#  29  programada                 4188 non-null   float64
#  30  realizadas                 4188 non-null   float64
#  31  Suprimidas                 4188 non-null   float64
#  32  atraso_percent             4188 non-null   float64
#  33  atraso_percent_0           4188 non-null   float64
#  34  atraso_percent_5           4188 non-null   float64
#  35  atraso_percent_10          4188 non-null   float64
#  36  num_ocorrencia             467 non-null    float64
#  37  dsc_sintoma_trem_prej      464 non-null    object
#  38  DSC_AREA                   467 non-null    object
#  39  DSC_CAUSA                  0 non-null      float64
#  40  DSC_SINTOMA                467 non-null    object
#  41  expurgar                   4188 non-null   object
#  42  capacidade_6m2             3965 non-null   float64
#  43  ncarros                    3965 non-null   float64
#  44  n_TUE                      4087 non-null   float64
#  45  origem                     4188 non-null   object
#  46  destino                    4188 non-null   object
#  47  linha_comercial            4188 non-null   object
#  48  linha                      4188 non-null   object
#  49  km                         4188 non-null   float64
#  50  carro_km                   3965 non-null   float64
#  51  velocidade_km_h            4076 non-null   float64
# dtypes: datetime64[ns](1), float64(22), object(29)
# memory usage: 1.7+ MB

# %%
df.head()
# Out:
#         data tipo_prefixo prefixo    nome_ramal composicao  ar serie extra  \
# 0 2020-09-21           UA   UA003  Belford Roxo       2018  AR  2000   NÃO
# 1 2020-09-21           UA   UA004  Belford Roxo        711  AR   700   NÃO
# 2 2020-09-21           UA   UA005  Belford Roxo        716  AR   700   NÃO
# 3 2020-09-21           UA   UA006  Belford Roxo        714  AR   700   NÃO
# 4 2020-09-21           UA   UA007  Belford Roxo        717  AR   700   NÃO
#
#    qtd_extras partida_real  ...  capacidade_6m2 ncarros n_TUE origem  destino  \
# 0         0.0     05:19:24  ...          1200.0     4.0   1.0    DPO      BRX
# 1         0.0     05:10:39  ...          1200.0     4.0   1.0    BRX      DPO
# 2         0.0     05:47:55  ...          1200.0     4.0   1.0    DPO      BRX
# 3         0.0     05:33:45  ...          1200.0     4.0   1.0    BRX      DPO
# 4         0.0     06:14:00  ...          1200.0     4.0   1.0    DPO      BRX
#
#   linha_comercial         linha         km    carro_km velocidade_km_h
# 0         DPO-BRX  Belford Roxo  32.849998  131.399994       26.999998
# 1         BRX-DPO  Belford Roxo  32.849998  131.399994       28.565217
# 2         DPO-BRX  Belford Roxo  32.849998  131.399994       27.760563
# 3         BRX-DPO  Belford Roxo  32.849998  131.399994       27.760563
# 4         DPO-BRX  Belford Roxo  32.849998  131.399994       30.323074
#
# [5 rows x 52 columns]

# %%
df.set_index('data', inplace = True)

# %%
df.head()
# Out:
#            tipo_prefixo prefixo    nome_ramal composicao  ar serie extra  \
# data
# 2020-09-21           UA   UA003  Belford Roxo       2018  AR  2000   NÃO
# 2020-09-21           UA   UA004  Belford Roxo        711  AR   700   NÃO
# 2020-09-21           UA   UA005  Belford Roxo        716  AR   700   NÃO
# 2020-09-21           UA   UA006  Belford Roxo        714  AR   700   NÃO
# 2020-09-21           UA   UA007  Belford Roxo        717  AR   700   NÃO
#
#             qtd_extras partida_real  hora_real  ... capacidade_6m2 ncarros  \
# data                                            ...
# 2020-09-21         0.0     05:19:24        5.0  ...         1200.0     4.0
# 2020-09-21         0.0     05:10:39        5.0  ...         1200.0     4.0
# 2020-09-21         0.0     05:47:55        5.0  ...         1200.0     4.0
# 2020-09-21         0.0     05:33:45        5.0  ...         1200.0     4.0
# 2020-09-21         0.0     06:14:00        6.0  ...         1200.0     4.0
#
#            n_TUE  origem destino linha_comercial         linha         km  \
# data
# 2020-09-21   1.0     DPO     BRX         DPO-BRX  Belford Roxo  32.849998
# 2020-09-21   1.0     BRX     DPO         BRX-DPO  Belford Roxo  32.849998
# 2020-09-21   1.0     DPO     BRX         DPO-BRX  Belford Roxo  32.849998
# 2020-09-21   1.0     BRX     DPO         BRX-DPO  Belford Roxo  32.849998
# 2020-09-21   1.0     DPO     BRX         DPO-BRX  Belford Roxo  32.849998
#
#               carro_km velocidade_km_h
# data
# 2020-09-21  131.399994       26.999998
# 2020-09-21  131.399994       28.565217
# 2020-09-21  131.399994       27.760563
# 2020-09-21  131.399994       27.760563
# 2020-09-21  131.399994       30.323074
#
# [5 rows x 51 columns]

# %% [markdown]
# #### Pré-processamento

# %%
# eliminate spaces in column names
df.rename(columns = lambda x: x.replace(' ', '_'), inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4188 entries, 2020-09-21 to 2020-09-27
# Data columns (total 51 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   tipo_prefixo               4188 non-null   object
#  1   prefixo                    4188 non-null   object
#  2   nome_ramal                 4188 non-null   object
#  3   composicao                 4087 non-null   object
#  4   ar                         3726 non-null   object
#  5   serie                      3965 non-null   object
#  6   extra                      4188 non-null   object
#  7   qtd_extras                 4188 non-null   float64
#  8   partida_real               4078 non-null   object
#  9   hora_real                  4078 non-null   float64
#  10  periodo_real               4078 non-null   object
#  11  chegada_real               4180 non-null   object
#  12  partida_programada         4188 non-null   object
#  13  hora_programada            4188 non-null   float64
#  14  periodo_prog               4188 non-null   object
#  15  chegada_programada         4188 non-null   object
#  16  maquinista                 4185 non-null   object
#  17  servico                    3367 non-null   object
#  18  tipo_viagem                4188 non-null   object
#  19  viagem_comercial           4188 non-null   object
#  20  descricao_sentido          4188 non-null   object
#  21  siof_viagem_id             4188 non-null   float64
#  22  fluxo_realizados           4188 non-null   object
#  23  fluxo_Programado           4188 non-null   object
#  24  suprimido                  4188 non-null   object
#  25  tempo_percurso_real        4077 non-null   float64
#  26  tempo_percurso_programado  4188 non-null   float64
#  27  min_atraso                 4076 non-null   float64
#  28  programada                 4188 non-null   float64
#  29  realizadas                 4188 non-null   float64
#  30  Suprimidas                 4188 non-null   float64
#  31  atraso_percent             4188 non-null   float64
#  32  atraso_percent_0           4188 non-null   float64
#  33  atraso_percent_5           4188 non-null   float64
#  34  atraso_percent_10          4188 non-null   float64
#  35  num_ocorrencia             467 non-null    float64
#  36  dsc_sintoma_trem_prej      464 non-null    object
#  37  DSC_AREA                   467 non-null    object
#  38  DSC_CAUSA                  0 non-null      float64
#  39  DSC_SINTOMA                467 non-null    object
#  40  expurgar                   4188 non-null   object
#  41  capacidade_6m2             3965 non-null   float64
#  42  ncarros                    3965 non-null   float64
#  43  n_TUE                      4087 non-null   float64
#  44  origem                     4188 non-null   object
#  45  destino                    4188 non-null   object
#  46  linha_comercial            4188 non-null   object
#  47  linha                      4188 non-null   object
#  48  km                         4188 non-null   float64
#  49  carro_km                   3965 non-null   float64
#  50  velocidade_km_h            4076 non-null   float64
# dtypes: float64(22), object(29)
# memory usage: 1.7+ MB

# %% [markdown]
# #### Valores faltantes

# %% [markdown]
# Vamos saber quais colunas tem NaN - Método I

# %%
def NaN_percent(df, column_name):
    #me dá a posição 0 do resultado de df.shape
    row_count = df[column_name].shape[0]
    #df.count() conta os valores não vazios
    empty_values = row_count - df[column_name].count()
    return (100.0 * empty_values)/row_count

# %%
for i in list(df):
    #str() converts a number into a string
    print(i + ': ' + str(NaN_percent(df,i))+'%')
# Out:
# tipo_prefixo: 0.0%
# prefixo: 0.0%
# nome_ramal: 0.0%
# composicao: 2.4116523400191023%
# ar: 11.031518624641834%
# serie: 5.324737344794651%
# extra: 0.0%
# qtd_extras: 0.0%
# partida_real: 2.626552053486151%
# hora_real: 2.626552053486151%
# periodo_real: 2.626552053486151%
# chegada_real: 0.19102196752626552%
# partida_programada: 0.0%
# hora_programada: 0.0%
# periodo_prog: 0.0%
# chegada_programada: 0.0%
# maquinista: 0.07163323782234957%
# servico: 19.603629417383%
# tipo_viagem: 0.0%
# viagem_comercial: 0.0%
# descricao_sentido: 0.0%
# siof_viagem_id: 0.0%
# fluxo_realizados: 0.0%
# fluxo_Programado: 0.0%
# suprimido: 0.0%
# tempo_percurso_real: 2.650429799426934%
# tempo_percurso_programado: 0.0%
# min_atraso: 2.6743075453677174%
# programada: 0.0%
# realizadas: 0.0%
# Suprimidas: 0.0%
# atraso_percent: 0.0%
# atraso_percent_0: 0.0%
# atraso_percent_5: 0.0%
# atraso_percent_10: 0.0%
# num_ocorrencia: 88.84909264565425%
# dsc_sintoma_trem_prej: 88.9207258834766%
# DSC_AREA: 88.84909264565425%
# DSC_CAUSA: 100.0%
# DSC_SINTOMA: 88.84909264565425%
# expurgar: 0.0%
# capacidade_6m2: 5.324737344794651%
# ncarros: 5.324737344794651%
# n_TUE: 2.4116523400191023%
# origem: 0.0%
# destino: 0.0%
# linha_comercial: 0.0%
# linha: 0.0%
# km: 0.0%
# carro_km: 5.324737344794651%
# velocidade_km_h: 2.6743075453677174%

# %% [markdown]
# Vamos saber quais colunas tem NaN - Método II

# %%
# let's find out which columns are incomplete.
def check_col_complete(dataframe):
    len_ = len(dataframe)
    
    incomplete = []
    for col in dataframe.columns:
        complete = dataframe[col].count() == len_
        if complete:
            print('{: >23}: COMPLETE'.format(col))
        else:
            missing = len_ - dataframe[col].count()
            incomplete.append(col)
            print('{: >23}: MISSING {} VALUES ({:.1f}%)'.format(col, missing, missing * 100/len_))
        
    print('\nTotal number of items:', len_)
    
    return incomplete

incomplete_cols = check_col_complete(df)
# Out:
#            tipo_prefixo: COMPLETE
#                 prefixo: COMPLETE
#              nome_ramal: COMPLETE
#              composicao: MISSING 101 VALUES (2.4%)
#                      ar: MISSING 462 VALUES (11.0%)
#                   serie: MISSING 223 VALUES (5.3%)
#                   extra: COMPLETE
#              qtd_extras: COMPLETE
#            partida_real: MISSING 110 VALUES (2.6%)
#               hora_real: MISSING 110 VALUES (2.6%)
#            periodo_real: MISSING 110 VALUES (2.6%)
#            chegada_real: MISSING 8 VALUES (0.2%)
#      partida_programada: COMPLETE
#         hora_programada: COMPLETE
#            periodo_prog: COMPLETE
#      chegada_programada: COMPLETE
#              maquinista: MISSING 3 VALUES (0.1%)
#                 servico: MISSING 821 VALUES (19.6%)
#             tipo_viagem: COMPLETE
#        viagem_comercial: COMPLETE
#       descricao_sentido: COMPLETE
#          siof_viagem_id: COMPLETE
#        fluxo_realizados: COMPLETE
#        fluxo_Programado: COMPLETE
#               suprimido: COMPLETE
#     tempo_percurso_real: MISSING 111 VALUES (2.7%)
# tempo_percurso_programado: COMPLETE
#              min_atraso: MISSING 112 VALUES (2.7%)
#              programada: COMPLETE
#              realizadas: COMPLETE
#              Suprimidas: COMPLETE
#          atraso_percent: COMPLETE
#        atraso_percent_0: COMPLETE
#        atraso_percent_5: COMPLETE
#       atraso_percent_10: COMPLETE
#          num_ocorrencia: MISSING 3721 VALUES (88.8%)
#   dsc_sintoma_trem_prej: MISSING 3724 VALUES (88.9%)
#                DSC_AREA: MISSING 3721 VALUES (88.8%)
#               DSC_CAUSA: MISSING 4188 VALUES (100.0%)
#             DSC_SINTOMA: MISSING 3721 VALUES (88.8%)
#                expurgar: COMPLETE
#          capacidade_6m2: MISSING 223 VALUES (5.3%)
#                 ncarros: MISSING 223 VALUES (5.3%)
#                   n_TUE: MISSING 101 VALUES (2.4%)
#                  origem: COMPLETE
#                 destino: COMPLETE
#         linha_comercial: COMPLETE
#                   linha: COMPLETE
#                      km: COMPLETE
#                carro_km: MISSING 223 VALUES (5.3%)
#         velocidade_km_h: MISSING 112 VALUES (2.7%)
#
# Total number of items: 4188

# %% [markdown]
# #### Tratando valores faltantes

# %%
# stn_code, agency, sampling_date, location_monitoring_agency do not add much value to the 
# dataset in terms of information - previously known by the expert. Therefore, we can drop those columns.
#df_treated = df.drop(['stn_code', 'agency', 'sampling_date', 'location_monitoring_station'], axis=1)
df = df.drop(['DSC_CAUSA'], axis=1)

# %% [markdown]
# #### Análises estatísticas

# %%
# Generate descriptive statistics - only for float variabels - that summarize the central tendency, 
# dispersion, and shape of a dataset’s distribution, excluding NaN values.
df.describe()
# Out:
#         qtd_extras    hora_real  hora_programada  siof_viagem_id  \
# count  4188.000000  4078.000000      4188.000000    4.188000e+03
# mean      0.004298    12.360716        12.447230    4.193874e+06
# std       0.065426     5.745275         5.767598    1.366013e+03
# min       0.000000     0.000000         0.000000    4.191544e+06
# 25%       0.000000     7.000000         7.000000    4.192676e+06
# 50%       0.000000    13.000000        13.000000    4.193878e+06
# 75%       0.000000    17.000000        17.000000    4.195018e+06
# max       1.000000    23.000000        23.000000    4.196330e+06
#
#        tempo_percurso_real  tempo_percurso_programado    min_atraso  \
# count         4.077000e+03                4188.000000  4.076000e+03
# mean          2.804280e+05                  54.816141  2.804326e+05
# std           4.210622e+06                  31.009542  4.210998e+06
# min           0.000000e+00                   1.000000 -7.000000e+01
# 25%           2.100000e+01                  20.000000 -3.000000e+00
# 50%           5.200000e+01                  50.000000  0.000000e+00
# 75%           9.000000e+01                  90.000000  2.000000e+00
# max           6.350704e+07                 100.000000  6.350000e+07
#
#        programada   realizadas   Suprimidas  ...  atraso_percent_0  \
# count      4188.0  4188.000000  4188.000000  ...       4188.000000
# mean          1.0     0.967287     0.032713  ...          0.347899
# std           0.0     0.177904     0.177904  ...          0.476361
# min           1.0     0.000000     0.000000  ...          0.000000
# 25%           1.0     1.000000     0.000000  ...          0.000000
# 50%           1.0     1.000000     0.000000  ...          0.000000
# 75%           1.0     1.000000     0.000000  ...          1.000000
# max           1.0     1.000000     1.000000  ...          1.000000
#
#        atraso_percent_5  atraso_percent_10  num_ocorrencia  capacidade_6m2  \
# count       4188.000000        4188.000000      467.000000     3965.000000
# mean           0.163324           0.091691     3177.237687     2029.588903
# std            0.369705           0.288623      419.924080      652.224137
# min            0.000000           0.000000     2546.000000        0.000000
# 25%            0.000000           0.000000     2774.000000     1200.000000
# 50%            0.000000           0.000000     3380.000000     2400.000000
# 75%            0.000000           0.000000     3623.500000     2400.000000
# max            1.000000           1.000000     3743.000000     2400.000000
#
#            ncarros        n_TUE            km     carro_km  velocidade_km_h
# count  3965.000000  4087.000000   4188.000000  3965.000000     4.076000e+03
# mean      6.805044     1.812576    152.399433   227.001712     8.261445e+02
# std       2.088258     0.565017   1505.230661   159.996867     2.078016e+04
# min       0.000000     1.000000      1.090000     0.000000     3.240000e-06
# 25%       4.000000     2.000000     13.017500    84.720001     3.102857e+01
# 50%       8.000000     2.000000     25.340000   202.720001     3.487659e+01
# 75%       8.000000     2.000000     54.639999   437.119995     3.988302e+01
# max       8.000000     4.000000  18846.000000   490.239990     1.130370e+06
#
# [8 rows x 21 columns]

# %% [markdown]
# But, what if we have categorical data? How can we get a summary of categorical data? The value_counts() method will be useful in this case.

# %%
df.select_dtypes(include='object')
# Out:
#            tipo_prefixo prefixo    nome_ramal composicao   ar serie extra  \
# data
# 2020-09-21           UA   UA003  Belford Roxo       2018   AR  2000   NÃO
# 2020-09-21           UA   UA004  Belford Roxo        711   AR   700   NÃO
# 2020-09-21           UA   UA005  Belford Roxo        716   AR   700   NÃO
# 2020-09-21           UA   UA006  Belford Roxo        714   AR   700   NÃO
# 2020-09-21           UA   UA007  Belford Roxo        717   AR   700   NÃO
# ...                 ...     ...           ...        ...  ...   ...   ...
# 2020-09-27           WS   WS202    Santa Cruz  7120-7121  NaN    MK   NÃO
# 2020-09-27           WS   WS501    Santa Cruz         13  NaN   NaN   NÃO
# 2020-09-27           WS   WS503    Santa Cruz         13  NaN   NaN   NÃO
# 2020-09-27           WS   WS504    Santa Cruz         14  NaN   NaN   NÃO
# 2020-09-27           WS   WS506    Santa Cruz         13  NaN   NaN   NÃO
#
#            partida_real periodo_real chegada_real  ... fluxo_Programado  \
# data                                               ...
# 2020-09-21     05:19:24           PM     06:32:58  ...              não
# 2020-09-21     05:10:39           PM     06:19:23  ...              sim
# 2020-09-21     05:47:55           PM     06:58:32  ...              não
# 2020-09-21     05:33:45           PM     06:44:45  ...              sim
# 2020-09-21     06:14:00           PM     07:19:12  ...              não
# ...                 ...          ...          ...  ...              ...
# 2020-09-27     20:13:42           VN     20:50:03  ...              não
# 2020-09-27     20:28:13           VN     20:57:18  ...              não
# 2020-09-27     22:23:02           VN     22:48:27  ...              não
# 2020-09-27     17:35:08           PV     18:03:44  ...              não
# 2020-09-27     21:38:40           VN     21:53:13  ...              não
#
#            suprimido dsc_sintoma_trem_prej DSC_AREA DSC_SINTOMA expurgar  \
# data
# 2020-09-21         N                   NaN      NaN         NaN      não
# 2020-09-21         N                   NaN      NaN         NaN      não
# 2020-09-21         N                   NaN      NaN         NaN      não
# 2020-09-21         N                   NaN      NaN         NaN      não
# 2020-09-21         N                   NaN      NaN         NaN      não
# ...              ...                   ...      ...         ...      ...
# 2020-09-27         N                   NaN      NaN         NaN      não
# 2020-09-27         N                   NaN      NaN         NaN      não
# 2020-09-27         N                   NaN      NaN         NaN      não
# 2020-09-27         N                   NaN      NaN         NaN      não
# 2020-09-27         N                   NaN      NaN         NaN      não
#
#            origem destino linha_comercial         linha
# data
# 2020-09-21    DPO     BRX         DPO-BRX  Belford Roxo
# 2020-09-21    BRX     DPO         BRX-DPO  Belford Roxo
# 2020-09-21    DPO     BRX         DPO-BRX  Belford Roxo
# 2020-09-21    BRX     DPO         BRX-DPO  Belford Roxo
# 2020-09-21    DPO     BRX         DPO-BRX  Belford Roxo
# ...           ...     ...             ...           ...
# 2020-09-27    SEM     DEO         SEM-DEO    Santa Cruz
# 2020-09-27    DEO     SEM         DEO-SEM    Santa Cruz
# 2020-09-27    DEO     SEM         DEO-SEM    Santa Cruz
# 2020-09-27    SEM     DEO         SEM-DEO    Santa Cruz
# 2020-09-27    SEM     DEO         SEM-DEO    Santa Cruz
#
# [4188 rows x 29 columns]

# %%
mylist = list(df.select_dtypes(include=['object']).columns)

# %%
mylist
# Out:
# ['tipo_prefixo',
#  'prefixo',
#  'nome_ramal',
#  'composicao',
#  'ar',
#  'serie',
#  'extra',
#  'partida_real',
#  'periodo_real',
#  'chegada_real',
#  'partida_programada',
#  'periodo_prog',
#  'chegada_programada',
#  'maquinista',
#  'servico',
#  'tipo_viagem',
#  'viagem_comercial',
#  'descricao_sentido',
#  'fluxo_realizados',
#  'fluxo_Programado',
#  'suprimido',
#  'dsc_sintoma_trem_prej',
#  'DSC_AREA',
#  'DSC_SINTOMA',
#  'expurgar',
#  'origem',
#  'destino',
#  'linha_comercial',
#  'linha']

# %%
df['tipo_prefixo'].value_counts()
# Out:
# UH    1158
# UP    1000
# US     671
# UA     378
# WC     300
# WP     200
# WS     172
# WH     107
# UV      95
# UG      54
# WA      52
# WG       1
# Name: tipo_prefixo, dtype: int64

# %%
df['nome_ramal'].value_counts()
# Out:
# Saracuruna        1265
# Japeri            1200
# Santa Cruz         843
# Belford Roxo       430
# Deodoro            300
# Vila Inhomirim      95
# Guapimirim          55
# Name: nome_ramal, dtype: int64

# %%
df['composicao'].value_counts()
# Out:
# 3068                387
# 3047-3088           247
# 3051-3053           163
# 2016-2008            94
# 3054-3081            85
#                    ...
# 3095                  1
# 2362-200-201-202      1
# 10                    1
# 708-713               1
# 3063-3059             1
# Name: composicao, Length: 164, dtype: int64

# %%
df['serie'].value_counts()
# Out:
# 3000    2723
# 4000     270
# MK       239
# 700      233
# 2000     219
# 5000     186
# 500       59
# 900       36
# Name: serie, dtype: int64

# %%
df['maquinista'].value_counts()
# Out:
# ABRAHÃO MONTEIRO       110
# ENVIAR PRONTIDÃO 1      72
# WASHINGTON DIONÍSIO     59
# ENVIAR PRONTIDÃO 4      48
# MARCIO R. SANTOS        48
#                       ...
# SEBASTIÃO DAVID          1
# VITOR HUGO SISMIL        1
# EDSON ANSELMO            1
# CHRISTIAN VELASCO        1
# JORGE E. DA SILVA        1
# Name: maquinista, Length: 305, dtype: int64

# %%
df['tipo_viagem'].value_counts()
# Out:
# Viagem Comercial        3356
# Viagem Não-Comercial     832
# Name: tipo_viagem, dtype: int64

# %%
df['viagem_comercial'].value_counts()
# Out:
# S    3356
# N     832
# Name: viagem_comercial, dtype: int64

# %%
df['descricao_sentido'].value_counts()
# Out:
# Par      2106
# Ímpar    2082
# Name: descricao_sentido, dtype: int64

# %%
df.num_ocorrencia.value_counts()
# Out:
# 2903.0    104
# 3452.0     88
# 2774.0     62
# 3674.0     36
# 2546.0     33
# 3380.0     22
# 3694.0     17
# 3735.0     12
# 2557.0      8
# 3598.0      8
# 2744.0      8
# 3668.0      7
# 2556.0      6
# 3736.0      5
# 2559.0      5
# 3743.0      5
# 3730.0      4
# 3732.0      3
# 2743.0      3
# 3737.0      3
# 2558.0      3
# 3660.0      3
# 3689.0      3
# 3686.0      2
# 3706.0      2
# 3678.0      2
# 3739.0      1
# 3688.0      1
# 3649.0      1
# 3707.0      1
# 3691.0      1
# 3695.0      1
# 3667.0      1
# 3702.0      1
# 3672.0      1
# 3741.0      1
# 3720.0      1
# 3675.0      1
# 3677.0      1
# Name: num_ocorrencia, dtype: int64

# %%
df.DSC_SINTOMA[(df.num_ocorrencia == 2546)]
# Out:
# data
# 2020-09-21    Outras Relacionadas A Via Permanente
# 2020-09-21    Outras Relacionadas A Via Permanente
# 2020-09-21    Outras Relacionadas A Via Permanente
# 2020-09-21    Outras Relacionadas A Via Permanente
# 2020-09-21    Outras Relacionadas A Via Permanente
# 2020-09-22    Outras Relacionadas A Via Permanente
# 2020-09-22    Outras Relacionadas A Via Permanente
# 2020-09-22    Outras Relacionadas A Via Permanente
# 2020-09-22    Outras Relacionadas A Via Permanente
# 2020-09-22    Outras Relacionadas A Via Permanente
# 2020-09-22    Outras Relacionadas A Via Permanente
# 2020-09-22    Outras Relacionadas A Via Permanente
# 2020-09-22    Outras Relacionadas A Via Permanente
# 2020-09-22    Outras Relacionadas A Via Permanente
# 2020-09-23    Outras Relacionadas A Via Permanente
# 2020-09-23    Outras Relacionadas A Via Permanente
# 2020-09-23    Outras Relacionadas A Via Permanente
# 2020-09-23    Outras Relacionadas A Via Permanente
# 2020-09-23    Outras Relacionadas A Via Permanente
# 2020-09-24    Outras Relacionadas A Via Permanente
# 2020-09-24    Outras Relacionadas A Via Permanente
# 2020-09-25    Outras Relacionadas A Via Permanente
# 2020-09-25    Outras Relacionadas A Via Permanente
# 2020-09-25    Outras Relacionadas A Via Permanente
# 2020-09-25    Outras Relacionadas A Via Permanente
# 2020-09-25    Outras Relacionadas A Via Permanente
# 2020-09-25    Outras Relacionadas A Via Permanente
# 2020-09-25    Outras Relacionadas A Via Permanente
# 2020-09-25    Outras Relacionadas A Via Permanente
# 2020-09-26    Outras Relacionadas A Via Permanente
# 2020-09-26    Outras Relacionadas A Via Permanente
# 2020-09-26    Outras Relacionadas A Via Permanente
# 2020-09-26    Outras Relacionadas A Via Permanente
# Name: DSC_SINTOMA, dtype: object

# %%
df.dsc_sintoma_trem_prej[(df.num_ocorrencia == 2546)]
# Out:
# data
# 2020-09-21    UH014 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-21    UH008 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-21    UH012 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-21    UH006 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-21    UH086 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-22    UH090 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-22    UH091 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-22    UH088 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-22    UH086 ATRASOU 6' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-22    UH082 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-22    UH078 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-22    UH079 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-22    UH015 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-22    UH050 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-23    UH048 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-23    UH046 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-23    UH044 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-23    UH036 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-23    UH034 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-24    UH085 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-24    UH038 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-25    UH086 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-25    UH022 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-25    UH080 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-25    UH032 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-25    UH072 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-25    UH020 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-25    UH008 ATRASOU 2' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-25    UH002 ATRASOU 3' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-26    UH736 ATRASOU 4' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-26    UH734 ATRASOU 4' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-26    UH731 ATRASOU 4' NO PERCURSO DEVIDO RESTRICAO ...
# 2020-09-26    UH732 ATRASOU 4' NO PERCURSO DEVIDO RESTRICAO ...
# Name: dsc_sintoma_trem_prej, dtype: object

# %%
# excluir linhas com atraso_percent acima de 1
# excluir linhas com velocidade média acima de 100 km/h
# excluir linhas de W
df = df[df.atraso_percent <= 1]
df = df[df.velocidade_km_h <=100]
df = df[df.tipo_viagem == 'Viagem Comercial']

# %%
# Let's take a look at the 'length' feature 
df.plot.scatter(x = 'serie', y = 'atraso_percent', figsize=(12,6), ylim=(0, 1), 
                    title='Série vs Atraso Percentual');
#save_fig('Length vs Rating Count')

# %%
sns.boxplot(x = 'tipo_prefixo', y = 'atraso_percent', data = df)

# %%
sns.boxplot(x = 'tipo_prefixo', y = 'carro_km', data = df)

# %%
sns.boxplot(x = 'tipo_prefixo', y = 'velocidade_km_h', data = df)

# %%
sns.boxplot(x = 'nome_ramal', y = 'atraso_percent', data = df)

# %%
sns.boxplot(x = 'nome_ramal', y = 'carro_km', data = df)

# %%
sns.boxplot(x = 'nome_ramal', y = 'velocidade_km_h', data = df)

# %%
sns.boxplot(x = 'serie', y = 'atraso_percent', data = df)

# %%
sns.boxplot(x = 'serie', y = 'carro_km', data = df)

# %%
sns.boxplot(x = 'serie', y = 'velocidade_km_h', data = df)

# %% [markdown]
# # Segunda Parte

# %% [markdown]
# #### Data Viz

# %%
# easy way to plot all numeric columns
df.hist(figsize = (25, 25), layout = (10, 6), bins = 'auto')
plt.tight_layout()
#plt.savefig('firsthist.png')
plt.show()

# %%
# Histogram 

df.hist(figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000235194F69E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023516F8AAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000235185EF4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002351A6FF358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023516F77FD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002351A7A7668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002351A74B7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002351A388E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002351A388748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000235194906D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000235191F52B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023519260978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002351926E4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002351A6D3CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002351A710C50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023518FB1BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000235190E7748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023519441E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002351825A5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023518F1C2B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023518264EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002351A31ADD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002351A3C80F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002351A2DA358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002351A2B35C0>]],
#       dtype=object)

# %%
count, bin_edges = np.histogram(df['velocidade_km_h'])

# %%
df['velocidade_km_h'].plot (kind='hist', xticks = bin_edges)
plt.xlabel('Velocidade (km/h)')
plt.ylabel('Número de Viagens')
plt.grid()
plt.show()

# %% [markdown]
# What if we want to understand the relationship between these continuous variables? Could engine size possibly predict the price of the car?

# %%
df_temp = df[['nome_ramal', 'serie', 'atraso_percent']]

# %%
df_group = df_temp.groupby(['nome_ramal', 'serie'], as_index = False).mean()

# %%
df_group.sort_values(['atraso_percent'], ascending=[False])
# Out:
#         nome_ramal serie  atraso_percent
# 15      Saracuruna  4000        0.059096
# 8           Japeri   700        0.049570
# 6           Japeri   500        0.042281
# 13      Saracuruna  2000        0.040004
# 5           Japeri  4000        0.035652
# 7           Japeri  5000        0.032412
# 16      Saracuruna  5000        0.030847
# 14      Saracuruna  3000        0.025195
# 2     Belford Roxo   700        0.021014
# 12      Santa Cruz  5000        0.019163
# 4           Japeri  3000        0.018612
# 11      Santa Cruz  4000        0.017897
# 10      Santa Cruz  3000        0.014625
# 0     Belford Roxo  2000        0.012013
# 1     Belford Roxo  3000        0.007102
# 9           Japeri   900        0.004150
# 17  Vila Inhomirim    MK        0.002311
# 3       Guapimirim    MK        0.000000

# %% [markdown]
# A table of this form is not very easy to read. So, we can convert this table to a pivot table using the pivot() method, which would allow us to read this table in a better fashion.

# %%
df_pivot = df_group.pivot(index='nome_ramal', columns='serie')

# %%
df_pivot
# Out:
#                atraso_percent                                          \
# serie                    2000      3000      4000       500      5000
# nome_ramal
# Belford Roxo         0.012013  0.007102       NaN       NaN       NaN
# Guapimirim                NaN       NaN       NaN       NaN       NaN
# Japeri                    NaN  0.018612  0.035652  0.042281  0.032412
# Santa Cruz                NaN  0.014625  0.017897       NaN  0.019163
# Saracuruna           0.040004  0.025195  0.059096       NaN  0.030847
# Vila Inhomirim            NaN       NaN       NaN       NaN       NaN
#
#
# serie                700      900        MK
# nome_ramal
# Belford Roxo    0.021014      NaN       NaN
# Guapimirim           NaN      NaN  0.000000
# Japeri          0.049570  0.00415       NaN
# Santa Cruz           NaN      NaN       NaN
# Saracuruna           NaN      NaN       NaN
# Vila Inhomirim       NaN      NaN  0.002311

# %% [markdown]
# We can see the correlation between different variables using the corr() function. Then we can plot a heatmap over this output to visualize the results.

# %%
correlation_matrix = df.corr()

# %%
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# Let’s verify this relationship by plotting regression plots between these variables.

# %%
sns.regplot(x = 'velocidade_km_h',y = 'atraso_percent',data=df)

# %%
sns.pairplot(df, vars = ['atraso_percent', 'serie', 'tipo_prefixo', 'velocidade_km_h', 'carro_km'])

# %%
maiores_atrasos_composicao = df.sort_values('atraso_percent', ascending = False).head(20)
maiores_atrasos_composicao_trat = maiores_atrasos_composicao[['atraso_percent', 'composicao']]
maiores_atrasos_composicao_trat = maiores_atrasos_composicao_trat.set_index('composicao')

# %%
# bar plot - maiores atrasos
maiores_atrasos_composicao_trat.plot(kind = 'bar', figsize = (12,7), color = sns.color_palette("BuGn_r"))

# eliminate ticks and rotate labels
plt.tick_params(axis = 'both', which = 'both', length = 0)
plt.xticks(rotation = 60, fontsize = 12)

# plot title
plt.title('20 Maiores Atrasos Por Composição', fontsize = 20)

# plot labels
plt.xlabel('Composições', fontsize = 14)
plt.ylabel('Atraso Percentual', fontsize = 14)

# text above the bars displaying average rating
#for x, index in enumerate(maiores_atrasos_4.maquinista):
#    plt.text(x = x - 0.1, y = maiores_atrasos_4.loc['maquinista'], 
#             s='{:.2f}'.format(maiores_atrasos_4.loc['maquinista']), fontsize=12)
# Out:
# Text(0, 0.5, 'Atraso Percentual')

# %%
maiores_atrasos_maquinista = df.sort_values('atraso_percent', ascending = False).head(20)
maiores_atrasos_maquinista_trat = maiores_atrasos_maquinista[['atraso_percent', 'maquinista']]
maiores_atrasos_maquinista_trat = maiores_atrasos_maquinista_trat.set_index('maquinista')

# %%
# bar plot - maiores atrasos
maiores_atrasos_maquinista_trat.plot(kind = 'bar', figsize = (12,7), color = sns.color_palette("BuGn_r"))

# eliminate ticks and rotate labels
plt.tick_params(axis = 'both', which = 'both', length = 0)
plt.xticks(rotation = 60, fontsize = 12)

# plot title
plt.title('20 Maiores Atrasos Por Maquinista', fontsize = 20)

# plot labels
plt.xlabel('Maquinista', fontsize = 14)
plt.ylabel('Atraso Percentual', fontsize = 14)

# text above the bars displaying average rating
#for x, index in enumerate(maiores_atrasos_4.maquinista):
#    plt.text(x = x - 0.1, y = maiores_atrasos_4.loc['maquinista'], 
#             s='{:.2f}'.format(maiores_atrasos_4.loc['maquinista']), fontsize=12)
# Out:
# Text(0, 0.5, 'Atraso Percentual')

# %%
# Distplot

fig, ax2 = plt.subplots(2, 2, figsize=(8, 8))
sns.distplot(df['atraso_percent'],ax = ax2[0][0])
sns.distplot(df['min_atraso'],ax=ax2[0][1])
sns.distplot(df['carro_km'],ax=ax2[1][0])
sns.distplot(df['velocidade_km_h'],ax=ax2[1][1])
#sns.distplot(pima_data['Insulin'],ax=ax2[2][0])
#sns.distplot(pima_data['BMI'],ax=ax2[2][1])
#sns.distplot(pima_data['DiabetesPedigreeFunction'],ax=ax2[3][0])
#sns.distplot(pima_data['Age'],ax=ax2[3][1])

# %%
media_maiores_atrasos_maquinista = df.groupby('maquinista')['atraso_percent'].mean().nlargest(10)
media_maiores_atrasos_maquinista
# Out:
# maquinista
# RENATA MARQUES       0.185567
# LUIZ OCTÁVIO PAES    0.162991
# RAFAEL BOTELHO       0.129021
# LEANDRO MATTOS       0.118280
# JORGE SIQUEIRA       0.097933
# LUCIANO DA SILVA     0.092593
# JOSÉ HONORATO        0.085266
# BARBARA LOURENÇO     0.079023
# JOÃO B. JESUS        0.078571
# ROGERIO CASTRO       0.078014
# Name: atraso_percent, dtype: float64

# %%
media_maiores_atrasos_maquinista.plot(kind = 'bar', figsize = (12,7), color = sns.color_palette("BuGn_r"))

# eliminate ticks and rotate labels
plt.tick_params(axis = 'both', which = 'both', length = 0)
plt.xticks(rotation = 60, fontsize = 12)

# plot title
plt.title('10 Maiores Atrasos Por Maquinista (em média)', fontsize = 20)

# plot labels
plt.xlabel('Maquinista', fontsize = 14)
plt.ylabel('Atraso Percentual (em média)', fontsize = 14)

# text above the bars displaying average rating
#for x, index in enumerate(maiores_atrasos_4.maquinista):
#    plt.text(x = x - 0.1, y = maiores_atrasos_4.loc['maquinista'], 
#             s='{:.2f}'.format(maiores_atrasos_4.loc['maquinista']), fontsize=12)
# Out:
# Text(0, 0.5, 'Atraso Percentual (em média)')

# %%
media_maiores_atrasos_composicao = df.groupby('composicao')['atraso_percent'].mean().nlargest(10)
media_maiores_atrasos_composicao
# Out:
# composicao
# 712-702             0.231959
# 2362-200-201-202    0.195122
# 4016-4015           0.137778
# 503-518             0.087295
# 2007-2002           0.084734
# 506-502             0.071019
# 707-705             0.063628
# 3019-3001           0.058676
# 3018-3022           0.055674
# 704                 0.055556
# Name: atraso_percent, dtype: float64

# %%
media_maiores_atrasos_composicao.plot(kind = 'bar', figsize = (12,7), color = sns.color_palette("BuGn_r"))

# eliminate ticks and rotate labels
plt.tick_params(axis = 'both', which = 'both', length = 0)
plt.xticks(rotation = 60, fontsize = 12)

# plot title
plt.title('10 Maiores Atrasos Por Composição (em média)', fontsize = 20)

# plot labels
plt.xlabel('Composição', fontsize = 14)
plt.ylabel('Atraso Percentual (em média)', fontsize = 14)

# text above the bars displaying average rating
#for x, index in enumerate(maiores_atrasos_4.maquinista):
#    plt.text(x = x - 0.1, y = maiores_atrasos_4.loc['maquinista'], 
#             s='{:.2f}'.format(maiores_atrasos_4.loc['maquinista']), fontsize=12)
# Out:
# Text(0, 0.5, 'Atraso Percentual (em média)')

# %%
# gráfico de disperação entre atraso percentual e as 10 colunas mais correlacionadas
topcorr = df.corr(method = 'spearman')['atraso_percent'].sort_values()[:-1]
topcorr = topcorr.tail(10)
fig, ax = plt.subplots(5,2, figsize = (16, 12))
ax = ax.ravel()
j = 0
for i in topcorr.index:
    sns.regplot(i, 'atraso_percent', ax = ax[j], lowess = True, data = df, color = 'C0', line_kws={"color": "C1"},
               scatter_kws = {"alpha": 0.2})
    ax[j].set_title("Atraso Percentual vs {}".format(i))
    j += 1
plt.tight_layout()
#plt.savefig('Scatterplots.png')
plt.show()
# Out:
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)

# %%
# gráfico de disperação entre carro km e as 10 colunas mais correlacionadas
topcorr = df.corr(method = 'spearman')['carro_km'].sort_values()[:-1]
topcorr = topcorr.tail(10)
fig, ax = plt.subplots(5,2, figsize = (16, 12))
ax = ax.ravel()
j = 0
for i in topcorr.index:
    sns.regplot(i, 'carro_km', ax = ax[j], lowess = True, data = df, color = 'C0', line_kws={"color": "C1"},
               scatter_kws = {"alpha": 0.2})
    ax[j].set_title("Carro Km vs {}".format(i))
    j += 1
plt.tight_layout()
#plt.savefig('Scatterplots.png')
plt.show()
# Out:
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)

# %%
# gráfico de disperação entre velocidade média e as 10 colunas mais correlacionadas
topcorr = df.corr(method = 'spearman')['velocidade_km_h'].sort_values()[:-1]
topcorr = topcorr.tail(10)
fig, ax = plt.subplots(5,2, figsize = (16, 12))
ax = ax.ravel()
j = 0
for i in topcorr.index:
    sns.regplot(i, 'velocidade_km_h', ax = ax[j], lowess = True, data = df, color = 'C0', line_kws={"color": "C1"},
               scatter_kws = {"alpha": 0.2})
    ax[j].set_title("Velocidade Média (km/h) vs {}".format(i))
    j += 1
plt.tight_layout()
#plt.savefig('Scatterplots.png')
plt.show()
# Out:
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# C:\Users\arthu\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)

# %% [markdown]
# #### Análise de outputs (pode ser atrasos ou supressões)

# %%
# viés da base

fig1, ax1 = plt.subplots(1, 2, figsize = (8,8))

# mostra o número de observações usando barras
sns.countplot(df['atraso_percent_5'], ax = ax1[0])

# busca o percentual 
labels = 'A Hora', 'Atrasos 5%'

df.atraso_percent_5.value_counts().plot.pie(labels = labels, autopct = '%1.1f%%', shadow = True, startangle = 90)

# %%
sns.pairplot(df, vars = ['atraso_percent', 'velocidade_km_h', 'carro_km'], hue = 'atraso_percent_5')

# %%
# crosstab dá a tabela de frequencia 

pd.crosstab(df['composicao'], df['atraso_percent_5'])
# Out:
# atraso_percent_5  0.0  1.0
# composicao
# 2004-2015          36   17
# 2007-2002          11    5
# 2016-2008          68   19
# 2018               42    2
# 2302-201-202-205   19    0
# ...               ...  ...
# 720                 3    1
# 730-719             6    3
# 927-903             3    0
# 953-947             4    0
# 959-911             6    0
#
# [123 rows x 2 columns]

# %%
# categórica vs. contínua ---- outcome vs. pregnancies

fig, ax2 = plt.subplots(3, 2, figsize = (12, 8))
sns.boxplot(x = 'atraso_percent_5', y = 'carro_km', data = df, ax = ax2[0][0])
sns.barplot(df['atraso_percent_5'], df['carro_km'], ax = ax2[0][1])
sns.stripplot(df['atraso_percent_5'], df['carro_km'], jitter = True, ax = ax2[1][0])
sns.swarmplot(df['atraso_percent_5'], df['carro_km'], ax = ax2[1][1])
sns.violinplot(df['atraso_percent_5'], df['carro_km'], ax = ax2[2][0])
sns.countplot(x = 'carro_km', hue = 'atraso_percent_5', data = df, ax = ax2[2][1])

# %%
# categórica vs. contínua ---- outcome vs. pregnancies

fig, ax2 = plt.subplots(3, 2, figsize = (12, 8))
sns.boxplot(x = 'atraso_percent_5', y = 'velocidade_km_h', data = df, ax = ax2[0][0])
sns.barplot(df['atraso_percent_5'], df['velocidade_km_h'], ax = ax2[0][1])
sns.stripplot(df['atraso_percent_5'], df['velocidade_km_h'], jitter = True, ax = ax2[1][0])
sns.swarmplot(df['atraso_percent_5'], df['velocidade_km_h'], ax = ax2[1][1])
sns.violinplot(df['atraso_percent_5'], df['velocidade_km_h'], ax = ax2[2][0])
sns.countplot(x = 'velocidade_km_h', hue = 'atraso_percent_5', data = df, ax = ax2[2][1])

# %% [markdown]
# # Quarta Parte

# %% [markdown]
# ### Processamento textual

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
df_1 = df[~df['dsc_sintoma_trem_prej'].isnull()]

# %% [markdown]
# The distribution of Top trigrams before removing stop words

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

common_words = get_top_n_trigram(df_1['dsc_sintoma_trem_prej'], 20)

for word, freq in common_words:
    print(word, freq)

df5 = pd.DataFrame(common_words, columns = ['Descrição Sintoma CCO' , 'Contagem'])
# Out:
# restricao de velocidade 214
# incendio no bangalo 202
# op jonatas alexandre 163
# devido restricao de 141
# duque de caxias 133
# na superior de 109
# sistema de sinalizacao 106
# devido ctc 62 103
# ctc 62 inoperante 103
# no bangalo na 103
# bangalo na superior 103
# superior de japeri 103
# de japeri afetando 103
# japeri afetando todo 103
# afetando todo sistema 103
# todo sistema de 103
# de sinalizacao do 103
# sinalizacao do patio 103
# do act devido 100
# em japeri op 100

# %%
df_Japeri = df_1[df_1.nome_ramal == 'Japeri']

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

common_words = get_top_n_trigram(df_Japeri['dsc_sintoma_trem_prej'], 20)

for word, freq in common_words:
    print(word, freq)

dfJaperi = pd.DataFrame(common_words, columns = ['Descrição Sintoma CCO' , 'Contagem'])
# Out:
# incendio no bangalo 202
# na superior de 109
# devido ctc 62 103
# ctc 62 inoperante 103
# no bangalo na 103
# bangalo na superior 103
# superior de japeri 103
# de japeri afetando 103
# japeri afetando todo 103
# afetando todo sistema 103
# todo sistema de 103
# sistema de sinalizacao 103
# de sinalizacao do 103
# sinalizacao do patio 103
# do act devido 100
# em japeri op 100
# diferenca de tempo 99
# de tempo apos 99
# tempo apos correcao 99
# apos correcao do 99

# %%
df_Santa_Cruz = df_1[df_1.nome_ramal == 'Santa Cruz']

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

common_words = get_top_n_trigram(df_Santa_Cruz['dsc_sintoma_trem_prej'], 20)

for word, freq in common_words:
    print(word, freq)

dfSantaCruz = pd.DataFrame(common_words, columns = ['Descrição Sintoma CCO' , 'Contagem'])
# Out:
# restricao de velocidade 25
# obs ocorrencia numero 23
# de velocidade apos 20
# velocidade apos vistoria 20
# apos vistoria da 20
# vistoria da via 20
# da via permanente 20
# percurso do ramal 17
# no percurso do 16
# ramal de santa 16
# de santa cruz 16
# atrasou no percurso 15
# linha obs ocorrencia 14
# devido restricao de 13
# do ramal deodoro 13
# op jonatas alexandre 12
# santa cruz por 12
# cruz por circular 12
# por circular com 12
# circular com restricao 12

# %%
df_Saracuruna = df_1[df_1.nome_ramal == 'Saracuruna']

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

common_words = get_top_n_trigram(df_Saracuruna['dsc_sintoma_trem_prej'], 20)

for word, freq in common_words:
    print(word, freq)

dfSaracuruna = pd.DataFrame(common_words, columns = ['Descrição Sintoma CCO' , 'Contagem'])
# Out:
# restricao de velocidade 182
# duque de caxias 133
# devido restricao de 121
# de caxias op 84
# op jonatas alexandre 79
# de velocidade 20km 77
# velocidade 20km da 75
# plataforma de vigario 75
# de vigario geral 75
# vigario geral ate 75
# geral ate duque 75
# ate duque de 75
# percurso devido restricao 64
# devido bolsao de 61
# bolsao de lama 61
# de lama na 61
# lama na linha 61
# na linha inferior 61
# linha inferior de 61
# inferior de manguinhos 61

# %%
df_Belford_Roxo = df_1[df_1.nome_ramal == 'Belford Roxo']

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

common_words = get_top_n_trigram(df_Belford_Roxo['dsc_sintoma_trem_prej'], 20)

for word, freq in common_words:
    print(word, freq)

dfBelfordRoxo = pd.DataFrame(common_words, columns = ['Descrição Sintoma CCO' , 'Contagem'])
# Out:
# aguardando licenciamento devido 23
# licenciamento devido ctc 22
# devido ctc 21 22
# ctc 21 no 22
# 21 no jacarezinho 22
# no jacarezinho inoperante 22
# jacarezinho inoperante em 22
# inoperante em razao 22
# em razao de 22
# razao de vandalismo 22
# de vandalismo fibra 22
# vandalismo fibra optica 22
# fibra optica danificada 22
# optica danificada cose 22
# danificada cose numero 22
# cose numero sci0095492 22
# numero sci0095492 antiga 22
# sci0095492 antiga ocorrencia 22
# antiga ocorrencia numero 22
# ocorrencia numero 5203 22
